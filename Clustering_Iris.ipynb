# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from random import random
from scipy.spatial import distance
obj_dataset = load_iris()
data_whole = obj_dataset.data
xydata_feature=data_whole[:100,[1,2]]
xdata_feature= data_whole[:100,[1]]
ydata_feature= data_whole[:100,[2]]
#print(len(data))
#print(data)
plt.scatter(xdata_feature,ydata_feature)
plt.show()

centriod1=[[6,2]]
centriod2=[[0,2]]
print(centriod)
count=0
for i in range(0,20):
    list_centriod1=[]
    list_centriod2=[]
    for i in range(0,len(xydata_feature)):
        dist_1 = distance.euclidean(centriod1[count],xydata_feature[i])
        dist_2 = distance.euclidean(centriod2[count],xydata_feature[i])
        if(dist_1>dist_2):
            list_centriod2.append(xydata_feature[i])
        else:
            list_centriod1.append(xydata_feature[i])
    new_x_centriod1=new_y_centriod1=new_x_centriod2=new_y_centriod2=0.0        
    for i in range(0,len(list_centriod1)):
        new_x_centriod1=new_x_centriod1+list_centriod1[i][0]
        new_y_centriod1=new_y_centriod1+list_centriod1[i][1]    
    for i in range(0,len(list_centriod2)):
        new_x_centriod2=new_x_centriod2+list_centriod2[i][0]
        new_y_centriod2=new_y_centriod2+list_centriod2[i][1]  
    array_centriod1=np.array(list_centriod1)
    array_centriod2=np.array(list_centriod2)
    print(array_centriod1.shape)
    print(array_centriod2.shape)
    xarray_centriod1=array_centriod1[:,[0]]
    yarray_centriod1=array_centriod1[:,[1]]
    xarray_centriod2=array_centriod2[:,[0]]
    yarray_centriod2=array_centriod2[:,[1]]

    plt.scatter(xarray_centriod1,yarray_centriod1,color='red')
    plt.scatter(xarray_centriod2,yarray_centriod2)
    
    centriod1.append([new_x_centriod1/(len(list_centriod1)+1),new_y_centriod1/(len(list_centriod1)+1)])
    #centriod1[count+1].append(new_y_centriod1/len(list_centriod1))
    plt.scatter(new_x_centriod1/(len(list_centriod1)+1),new_y_centriod1/(len(list_centriod1)+1),color='yellow')
    centriod2.append([new_x_centriod2/(len(list_centriod2)+1),new_y_centriod2/(len(list_centriod2)+1)])
    plt.scatter(new_x_centriod2/(len(list_centriod2)+1),new_y_centriod2/(len(list_centriod2)+1),color='yellow')   
    #centriod2[count+1].append(new_y_centriod2/len(list_centriod2)) 
    plt.show()
    count=count+1
    
print(centriod1)
print(centriod2)
#plt.scatter(centriod1)
#plt.scatter(centriod1)
print()
# Out:
# [[]]
# (64, 2)
# (36, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# (50, 2)
# ...
